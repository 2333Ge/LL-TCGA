# %% [markdown]
# 忽略，暂时留着这个文件，用python写了一半

# %%
import pandas as pd

df = pd.read_csv('gdc\\000b6b94-572d-4d06-a8f4-2e43829f83d4\\e74f321c-217f-4bdc-ad17-f132501b5157.rna_seq.augmented_star_gene_counts.tsv',delimiter='\t')
print(df)
# Out:
#                                                                                                                      # gene-model: GENCODE v36
# gene_id           gene_name  gene_type      unstranded stranded_first stranded_second tpm_unstranded fpkm_unstranded        fpkm_uq_unstranded
# N_unmapped        NaN        NaN            1887608    1887608        1887608         NaN            NaN                                   NaN
# N_multimapping    NaN        NaN            5759304    5759304        5759304         NaN            NaN                                   NaN
# N_noFeature       NaN        NaN            4674688    29409259       29441458        NaN            NaN                                   NaN
# N_ambiguous       NaN        NaN            5869664    1506278        1503128         NaN            NaN                                   NaN
# ...

# %%
import json
import pandas as pd

# 读取JSON文件
with open('./metadata.cart.2023-09-21.json', 'r') as file:
    json_data = file.read()

# 解析JSON数据
data = json.loads(json_data)

# 将数据转换为DataFrame
df = pd.DataFrame(data)

# 显示DataFrame
df
# Out:
#      data_format access                                associated_entities  \
# 0            TSV   open  [{'entity_submitter_id': 'TCGA-69-7980-01A-11R...
# 1            TSV   open  [{'entity_submitter_id': 'TCGA-55-1592-01A-01R...
# 2            TSV   open  [{'entity_submitter_id': 'TCGA-55-7727-01A-11R...
# 3            TSV   open  [{'entity_submitter_id': 'TCGA-55-6972-01A-11R...
# 4            TSV   open  [{'entity_submitter_id': 'TCGA-44-2668-11A-01R...
# ...          ...    ...                                                ...
# 1148         TSV   open  [{'entity_submitter_id': 'TCGA-18-3411-01A-01R...
# 1149         TSV   open  [{'entity_submitter_id': 'TCGA-39-5039-01A-01R...
# 1150         TSV   open  [{'entity_submitter_id': 'TCGA-85-A4QR-01A-11R...
# 1151         TSV   open  [{'entity_submitter_id': 'TCGA-33-4582-01A-01R...
# 1152         TSV   open  [{'entity_submitter_id': 'TCGA-77-A5GB-01B-11R...
#
#                                               file_name  \
# ...
